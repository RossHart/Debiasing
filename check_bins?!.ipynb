# %%
from astropy.table import Table, column
import matplotlib.pyplot as plt

% matplotlib inline

# %%
gama_data = Table.read('GAMA_fits/gama09_less.fits')
#bins = Table.read('output_files/shape/star_or_artifact/all_bins.fits')
bins = Table.read('output_files/disk/yes/all_bins.fits')

# %%
for v in np.unique(bins['vbin']):
    in_v = bins['vbin'] == v
    print(v,np.sum(in_v))
    z_unique = np.unique(bins['zbin'][in_v])
    for z in z_unique:
        in_z = bins['zbin'][in_v] == z
        print(np.sum(in_z))
    print('----------')
# Out:
# -1 2318
# 1287
# 494
# 177
# 132
# 80
# 70
# 61
# 16
# 1
# ----------
# 0 432
# 225
# 65
# 55
# 39
# 24
# 12
# 11
# 1
# ----------
# 1 367
# 199
# 25
# 33
# 35
# 18
# 20
# 31
# 5
# 1
# ----------
# 2 592
# 300
# 36
# 57
# 49
# 38
# 45
# 49
# 15
# 3
# ----------
# 3 1227
# 671
# 130
# 129
# 109
# 78
# 54
# 37
# 19
# ----------
# 4 542
# 313
# 134
# 65
# 25
# 5
# ----------
# 5 853
# 459
# 57
# 67
# 70
# 49
# 48
# 77
# 24
# 2
# ----------
# 6 481
# 257
# 36
# 29
# 43
# 26
# 26
# 46
# 13
# 5
# ----------
# 7 1116
# 596
# 70
# 85
# 80
# 94
# 58
# 103
# 25
# 5
# ----------
# 8 196
# 110
# 15
# 8
# 18
# 8
# 12
# 19
# 5
# 1
# ----------
# 9 510
# 279
# 30
# 36
# 44
# 40
# 24
# 40
# 14
# 3
# ----------
# 10 724
# 386
# 49
# 64
# 57
# 46
# 39
# 57
# 21
# 5
# ----------
# 11 405
# 218
# 24
# 32
# 29
# 18
# 24
# 43
# 14
# 3
# ----------
# 12 512
# 277
# 33
# 45
# 39
# 36
# 24
# 39
# 16
# 3
# ----------
# 13 393
# 202
# 31
# 31
# 24
# 32
# 20
# 34
# 13
# 6
# ----------
# 14 369
# 181
# 24
# 32
# ...
